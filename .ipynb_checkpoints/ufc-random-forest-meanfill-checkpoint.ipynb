# %%
# Dependencies and Setup
import os
import pandas as pd

# %%
df = pd.read_csv(os.path.join("Resources", "ufc-master.csv"))
df = df.fillna(df.mean())

df.head()
# Out:
# C:\Users\nickm\anaconda3\envs\PythonAdv\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (79,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            R_fighter         B_fighter  R_odds  B_odds        R_ev  \
# 0   Alistair Overeem  Alexander Volkov     150    -182  150.000000
# 1     Cory Sandhagen     Frankie Edgar    -400     300   25.000000
# 2  Alexandre Pantoja        Manel Kape    -125     100   80.000000
# 3     Diego Ferreira    Beneil Dariush    -125     105   80.000000
# 4    Michael Johnson        Clay Guida    -225     175   44.444444
#
#          B_ev      date                location country Winner  ...  \
# 0   54.945055  2/6/2021  Las Vegas, Nevada, USA     USA   Blue  ...
# 1  300.000000  2/6/2021  Las Vegas, Nevada, USA     USA    Red  ...
# 2  100.000000  2/6/2021  Las Vegas, Nevada, USA     USA    Red  ...
# 3  105.000000  2/6/2021  Las Vegas, Nevada, USA     USA   Blue  ...
# 4  175.000000  2/6/2021  Las Vegas, Nevada, USA     USA   Blue  ...
#
#    R_td_attempted_bout B_td_attempted_bout R_td_pct_bout  B_td_pct_bout  \
# 0             3.107143            2.768759      0.293701       0.243701
# 1             3.107143            2.768759      0.293701       0.243701
# 2             3.107143            2.768759      0.293701       0.243701
# 3             3.107143            2.768759      0.293701       0.243701
# 4             3.107143            2.768759      0.293701       0.243701
#
#    R_sub_attempts_bout  B_sub_attempts_bout  R_pass_bout  B_pass_bout  \
# 0             0.403319              0.33189     1.245671     0.920274
# 1             0.403319              0.33189     1.245671     0.920274
# 2             0.403319              0.33189     1.245671     0.920274
# 3             0.403319              0.33189     1.245671     0.920274
# 4             0.403319              0.33189     1.245671     0.920274
#
#    R_rev_bout  B_rev_bout
# 0    0.137807    0.138889
# 1    0.137807    0.138889
# 2    0.137807    0.138889
# 3    0.137807    0.138889
# 4    0.137807    0.138889
#
# [5 rows x 137 columns]

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum().sort_values(ascending=False)
# Out:
# B_Women's Featherweight_rank    4566
# B_match_weightclass_rank        3754
# R_match_weightclass_rank        3333
# finish_details                  2542
# finish_round_time                467
# finish                           448
# better_rank                       10
# R_avg_TD_pct                       0
# R_avg_TD_landed                    0
# R_avg_SUB_ATT                      0
# R_avg_SIG_STR_pct                  0
# B_rev_bout                         0
# R_losses                           0
# R_avg_SIG_STR_landed               0
# R_draw                             0
# R_current_win_streak               0
# R_current_lose_streak              0
# B_Weight_lbs                       0
# B_Reach_cms                        0
# R_longest_win_streak               0
# R_total_rounds_fought              0
# B_Stance                           0
# R_Stance                           0
# lose_streak_dif                    0
# B_age                              0
# R_age                              0
# R_Weight_lbs                       0
# R_Reach_cms                        0
# R_Height_cms                       0
# R_wins                             0
# R_total_title_bouts                0
# R_win_by_TKO_Doctor_Stoppage       0
# R_win_by_Submission                0
# R_win_by_KO/TKO                    0
# R_win_by_Decision_Unanimous        0
# R_win_by_Decision_Split            0
# R_win_by_Decision_Majority         0
# B_Height_cms                       0
# B_win_by_TKO_Doctor_Stoppage       0
# B_wins                             0
# B_current_win_streak               0
# B_fighter                          0
# R_odds                             0
# B_odds                             0
# R_ev                               0
# B_ev                               0
# date                               0
# location                           0
# country                            0
# Winner                             0
# title_bout                         0
# weight_class                       0
# gender                             0
# no_of_rounds                       0
# B_current_lose_streak              0
# B_draw                             0
# longest_win_streak_dif             0
# B_avg_SIG_STR_landed               0
# B_avg_SIG_STR_pct                  0
# B_avg_SUB_ATT                      0
# B_avg_TD_landed                    0
# B_avg_TD_pct                       0
# B_longest_win_streak               0
# B_losses                           0
# B_total_rounds_fought              0
# B_total_title_bouts                0
# B_win_by_Decision_Majority         0
# B_win_by_Decision_Split            0
# B_win_by_Decision_Unanimous        0
# B_win_by_KO/TKO                    0
# B_win_by_Submission                0
# win_streak_dif                     0
# total_title_bout_dif               0
# win_dif                            0
# loss_dif                           0
# B_Lightweight_rank                 0
# B_Featherweight_rank               0
# B_Bantamweight_rank                0
# B_Flyweight_rank                   0
# B_Pound-for-Pound_rank             0
# finish_round                       0
# total_fight_time_secs              0
# R_kd_bout                          0
# B_kd_bout                          0
# R_sig_str_landed_bout              0
# B_sig_str_landed_bout              0
# R_sig_str_attempted_bout           0
# B_sig_str_attempted_bout           0
# R_sig_str_pct_bout                 0
# B_sig_str_pct_bout                 0
# R_tot_str_landed_bout              0
# B_tot_str_landed_bout              0
# R_tot_str_attempted_bout           0
# B_tot_str_attempted_bout           0
# R_td_landed_bout                   0
# B_td_landed_bout                   0
# R_td_attempted_bout                0
# B_td_attempted_bout                0
# R_td_pct_bout                      0
# B_td_pct_bout                      0
# R_sub_attempts_bout                0
# B_sub_attempts_bout                0
# R_pass_bout                        0
# B_pass_bout                        0
# B_Welterweight_rank                0
# B_Middleweight_rank                0
# B_Light Heavyweight_rank           0
# R_Women's Featherweight_rank       0
# total_round_dif                    0
# R_rev_bout                         0
# ko_dif                             0
# sub_dif                            0
# height_dif                         0
# reach_dif                          0
# age_dif                            0
# sig_str_dif                        0
# avg_sub_att_dif                    0
# avg_td_dif                         0
# empty_arena                        0
# constant_1                         0
# R_Women's Flyweight_rank           0
# R_Women's Strawweight_rank         0
# B_Heavyweight_rank                 0
# R_Women's Bantamweight_rank        0
# R_Heavyweight_rank                 0
# R_Light Heavyweight_rank           0
# R_Middleweight_rank                0
# R_Welterweight_rank                0
# R_Lightweight_rank                 0
# R_Featherweight_rank               0
# R_Bantamweight_rank                0
# R_Flyweight_rank                   0
# R_Pound-for-Pound_rank             0
# B_Women's Flyweight_rank           0
# B_Women's Strawweight_rank         0
# B_Women's Bantamweight_rank        0
# R_fighter                          0
# dtype: int64

# %%
# Set features and target
X = df.drop(["Winner", "B_Women's Featherweight_rank"], axis=1)
y = df["Winner"]

feature_names = X.columns

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
non_numeric = [i for i in X.columns if X[i].dtypes == 'object']
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

for i in X[non_numeric]:
    X[i] = label_encoder.fit_transform(X[i].astype(str))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, encoded_y, random_state=42)

X_train.head()
# Out:
#       R_fighter  B_fighter  R_odds  B_odds        R_ev        B_ev  date  \
# 1456        363         57    -135     115   74.074074  115.000000    13
# 2934       1183       1399    -365     328   27.397260  328.000000    94
# 2451       1024        391    -440     350   22.727273  350.000000    76
# 286         185        324    -286     220   29.850746  245.000000   300
# 1504         58        479     210    -230  210.000000   43.478261   117
#
#       location  country  title_bout  ...  R_td_attempted_bout  \
# 1456        22       21       False  ...            12.000000
# 2934       137        2       False  ...             3.107143
# 2451        81       12       False  ...             6.000000
# 286          0       27       False  ...             3.107143
# 1504        39       21       False  ...             3.107143
#
#       B_td_attempted_bout  R_td_pct_bout  B_td_pct_bout  R_sub_attempts_bout  \
# 1456             1.000000       0.580000       1.000000             0.000000
# 2934             2.768759       0.293701       0.243701             0.403319
# 2451             2.000000       0.500000       0.500000             0.000000
# 286              2.768759       0.293701       0.243701             0.403319
# 1504             2.768759       0.293701       0.243701             0.403319
#
#       B_sub_attempts_bout  R_pass_bout  B_pass_bout  R_rev_bout  B_rev_bout
# 1456              2.00000     1.000000     4.000000    2.000000    2.000000
# 2934              0.33189     1.245671     0.920274    0.137807    0.138889
# 2451              0.00000     0.000000     0.000000    0.000000    0.000000
# 286               0.33189     1.245671     0.920274    0.137807    0.138889
# 1504              0.33189     1.245671     0.920274    0.137807    0.138889
#
# [5 rows x 135 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=200)
rfc = rfc.fit(X_train, y_train)

# %%
print(rfc.score(X_test, y_test))
# Out:
# 0.7810858143607706

# %%
sorted(zip(rfc.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.03632338321455201, 'B_odds'),
#  (0.03408348555919331, 'B_ev'),
#  (0.034009947831865714, 'R_odds'),
#  (0.031536956113984244, 'R_ev'),
#  (0.030168727387545863, 'B_kd_bout'),
#  (0.023651162934219813, 'R_tot_str_landed_bout'),
#  (0.022919725504726794, 'R_sig_str_pct_bout'),
#  (0.01858103442500575, 'B_sig_str_pct_bout'),
#  (0.017360244352075928, 'B_sig_str_landed_bout'),
#  (0.01697736713635417, 'B_tot_str_landed_bout'),
#  (0.016848567025924487, 'R_kd_bout'),
#  (0.01674092559599363, 'B_pass_bout'),
#  (0.016497040612115193, 'R_fighter'),
#  (0.016321686768792573, 'R_sig_str_landed_bout'),
#  (0.016179960812974545, 'date'),
#  (0.015643775744136865, 'R_pass_bout'),
#  (0.0153152803208996, 'B_td_pct_bout'),
#  (0.014826452721182748, 'R_avg_SIG_STR_pct'),
#  (0.01470062210497329, 'B_fighter'),
#  (0.01354640778233763, 'sig_str_dif'),
#  (0.013403846949583933, 'R_avg_SIG_STR_landed'),
#  (0.013335577865804115, 'R_tot_str_attempted_bout'),
#  (0.01316166714662362, 'B_tot_str_attempted_bout'),
#  (0.012960425873743981, 'age_dif'),
#  (0.01258810851778003, 'B_avg_SIG_STR_pct'),
#  (0.012507242414809825, 'B_avg_SIG_STR_landed'),
#  (0.01222656242323701, 'avg_td_dif'),
#  (0.012155429605853424, 'R_avg_TD_pct'),
#  (0.011581255958332124, 'B_age'),
#  (0.01156556113334764, 'R_avg_TD_landed'),
#  (0.011366863535073704, 'R_age'),
#  (0.011243232260924888, 'location'),
#  (0.010855266002198695, 'reach_dif'),
#  (0.010733876417779977, 'total_round_dif'),
#  (0.01070211171763554, 'B_sig_str_attempted_bout'),
#  (0.010498020012864305, 'R_td_pct_bout'),
#  (0.010049441981592331, 'R_sig_str_attempted_bout'),
#  (0.009966831248937226, 'B_td_landed_bout'),
#  (0.009726573366346422, 'total_fight_time_secs'),
#  (0.009702256071500517, 'R_Reach_cms'),
#  (0.009593222447000197, 'avg_sub_att_dif'),
#  (0.009553464522321756, 'B_Reach_cms'),
#  (0.00941709721214681, 'R_total_rounds_fought'),
#  (0.009264733928378241, 'R_sub_attempts_bout'),
#  (0.009251760011275822, 'R_Height_cms'),
#  (0.009127185247476135, 'B_avg_TD_landed'),
#  (0.009041706308058747, 'B_avg_TD_pct'),
#  (0.009038699592009604, 'height_dif'),
#  (0.008801359167063066, 'finish_round_time'),
#  (0.00844474470612145, 'B_Height_cms'),
#  (0.008111175663247868, 'R_avg_SUB_ATT'),
#  (0.008109290446860202, 'finish'),
#  (0.00807963197506429, 'loss_dif'),
#  (0.007626716394478032, 'B_total_rounds_fought'),
#  (0.00756272881321002, 'win_dif'),
#  (0.007363952651566292, 'country'),
#  (0.007330597852861373, 'finish_details'),
#  (0.007173774296608551, 'B_sub_attempts_bout'),
#  (0.007114888799464264, 'R_td_landed_bout'),
#  (0.007096087445473007, 'B_avg_SUB_ATT'),
#  (0.007054628727515637, 'weight_class'),
#  (0.006954905050843136, 'R_Weight_lbs'),
#  (0.006769192506006147, 'R_wins'),
#  (0.006753639326894709, 'B_Weight_lbs'),
#  (0.006453842941614482, 'longest_win_streak_dif'),
#  (0.006096130625285789, 'R_td_attempted_bout'),
#  (0.006052460293781132, 'B_td_attempted_bout'),
#  (0.005698089411707641, 'R_losses'),
#  (0.0056825216020647005, 'ko_dif'),
#  (0.005371890252635499, 'win_streak_dif'),
#  (0.005271570269022571, 'sub_dif'),
#  (0.005176014097434678, 'B_wins'),
#  (0.005038936347332484, 'R_longest_win_streak'),
#  (0.004781636566099504, 'lose_streak_dif'),
#  (0.004443817785700482, 'B_losses'),
#  (0.004318760732793866, 'R_win_by_Decision_Unanimous'),
#  (0.004266342996839677, 'B_longest_win_streak'),
#  (0.004163934662642281, 'R_win_by_KO/TKO'),
#  (0.004106695810255098, 'finish_round'),
#  (0.0039195899648684866, 'R_current_win_streak'),
#  (0.0038231875919450408, 'R_match_weightclass_rank'),
#  (0.0035686467095600973, 'B_win_by_Decision_Unanimous'),
#  (0.003555601160146963, 'B_current_win_streak'),
#  (0.003468767127783108, 'B_current_lose_streak'),
#  (0.0032580263015868087, 'R_win_by_Submission'),
#  (0.0031872074216636645, 'R_current_lose_streak'),
#  (0.003101625406474253, 'B_win_by_KO/TKO'),
#  (0.0029713938554695838, 'total_title_bout_dif'),
#  (0.00276968977896184, 'R_win_by_Decision_Split'),
#  (0.002697679801513604, 'B_Stance'),
#  (0.0026593837829211268, 'B_win_by_Submission'),
#  (0.00257885264930015, 'R_Stance'),
#  (0.0024019683902031575, 'B_match_weightclass_rank'),
#  (0.002276176886681329, 'R_total_title_bouts'),
#  (0.0019604791540977344, 'B_win_by_Decision_Split'),
#  (0.001667080361515363, 'B_rev_bout'),
#  (0.001622552543245796, 'R_rev_bout'),
#  (0.0014633516055292009, 'better_rank'),
#  (0.0013235033562923526, 'B_total_title_bouts'),
#  (0.001267664837820766, 'R_Heavyweight_rank'),
#  (0.0011145195562094726, 'R_Middleweight_rank'),
#  (0.0010929550818182896, "B_Women's Bantamweight_rank"),
#  (0.0010123560138680886, "R_Women's Bantamweight_rank"),
#  (0.0010001669034323632, 'R_Welterweight_rank'),
#  (0.0009748687965828617, 'R_win_by_Decision_Majority'),
#  (0.0009600054041145937, 'no_of_rounds'),
#  (0.0009335034410068114, 'empty_arena'),
#  (0.0008731018816023219, 'gender'),
#  (0.0008387000440087277, 'R_Lightweight_rank'),
#  (0.0007687285464925691, 'R_Bantamweight_rank'),
#  (0.000747272969866223, 'R_Light Heavyweight_rank'),
#  (0.0007034908384323125, 'B_draw'),
#  (0.000693292272879002, 'title_bout'),
#  (0.000674803076708815, 'R_win_by_TKO_Doctor_Stoppage'),
#  (0.0006734082960106058, 'B_Light Heavyweight_rank'),
#  (0.0006639533333197119, 'B_Lightweight_rank'),
#  (0.0006347040765737323, 'R_Flyweight_rank'),
#  (0.0005915405528498782, 'R_Pound-for-Pound_rank'),
#  (0.0005871393059290945, 'R_Featherweight_rank'),
#  (0.0005466770873325409, 'B_Welterweight_rank'),
#  (0.000507227756926671, "R_Women's Strawweight_rank"),
#  (0.00041803550868953156, 'B_win_by_TKO_Doctor_Stoppage'),
#  (0.000411537446138983, 'B_Heavyweight_rank'),
#  (0.00035938898320698846, 'B_Bantamweight_rank'),
#  (0.00035686601857555495, 'B_Featherweight_rank'),
#  (0.00035657869439800874, 'B_Flyweight_rank'),
#  (0.00034054344084503534, 'B_win_by_Decision_Majority'),
#  (0.00033032932834508655, 'R_draw'),
#  (0.0003265276989036015, 'B_Middleweight_rank'),
#  (0.0002803659382667814, "B_Women's Flyweight_rank"),
#  (0.00025916055756976594, "R_Women's Flyweight_rank"),
#  (0.00013672150543218799, "B_Women's Strawweight_rank"),
#  (9.030213755040821e-05, 'B_Pound-for-Pound_rank'),
#  (7.806687855439725e-05, "R_Women's Featherweight_rank"),
#  (0.0, 'constant_1')]
