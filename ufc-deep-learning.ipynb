# %%
# Dependencies and Setup
import os
import pandas as pd

# %%
df = pd.read_csv(os.path.join("Resources", "ufc-master.csv"))
df = df.fillna(df.mean())

df.head()
# Out:
# C:\Users\nickm\anaconda3\envs\PythonAdv\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (79,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            R_fighter         B_fighter  R_odds  B_odds        R_ev  \
# 0   Alistair Overeem  Alexander Volkov     150    -182  150.000000
# 1     Cory Sandhagen     Frankie Edgar    -400     300   25.000000
# 2  Alexandre Pantoja        Manel Kape    -125     100   80.000000
# 3     Diego Ferreira    Beneil Dariush    -125     105   80.000000
# 4    Michael Johnson        Clay Guida    -225     175   44.444444
#
#          B_ev      date                location country Winner  ...  \
# 0   54.945055  2/6/2021  Las Vegas, Nevada, USA     USA   Blue  ...
# 1  300.000000  2/6/2021  Las Vegas, Nevada, USA     USA    Red  ...
# 2  100.000000  2/6/2021  Las Vegas, Nevada, USA     USA    Red  ...
# 3  105.000000  2/6/2021  Las Vegas, Nevada, USA     USA   Blue  ...
# 4  175.000000  2/6/2021  Las Vegas, Nevada, USA     USA   Blue  ...
#
#    R_td_attempted_bout B_td_attempted_bout R_td_pct_bout  B_td_pct_bout  \
# 0             3.107143            2.768759      0.293701       0.243701
# 1             3.107143            2.768759      0.293701       0.243701
# 2             3.107143            2.768759      0.293701       0.243701
# 3             3.107143            2.768759      0.293701       0.243701
# 4             3.107143            2.768759      0.293701       0.243701
#
#    R_sub_attempts_bout  B_sub_attempts_bout  R_pass_bout  B_pass_bout  \
# 0             0.403319              0.33189     1.245671     0.920274
# 1             0.403319              0.33189     1.245671     0.920274
# 2             0.403319              0.33189     1.245671     0.920274
# 3             0.403319              0.33189     1.245671     0.920274
# 4             0.403319              0.33189     1.245671     0.920274
#
#    R_rev_bout  B_rev_bout
# 0    0.137807    0.138889
# 1    0.137807    0.138889
# 2    0.137807    0.138889
# 3    0.137807    0.138889
# 4    0.137807    0.138889
#
# [5 rows x 137 columns]

# %%
# Set features and target
X = df[['B_ev','R_odds','R_ev','B_odds','B_kd_bout','R_tot_str_landed_bout', 'R_sig_str_pct_bout','B_tot_str_landed_bout', 'B_pass_bout',  'B_sig_str_landed_bout', 'B_sig_str_pct_bout', 'R_kd_bout','R_pass_bout','R_fighter',  'R_sig_str_landed_bout', 'date', 'R_tot_str_attempted_bout',  'B_fighter',  'R_avg_SIG_STR_pct', 'B_td_pct_bout',  'R_avg_TD_pct', 'sig_str_dif','R_avg_TD_landed', 'B_avg_SIG_STR_pct','B_avg_SIG_STR_landed' , 'age_dif', 'B_tot_str_attempted_bout','R_avg_SIG_STR_landed','avg_td_dif','location','B_age','B_td_landed_bout','R_age',  'reach_dif',  'total_round_dif', 'B_avg_TD_landed','B_sig_str_attempted_bout', 'R_sig_str_attempted_bout']]
y = df["Winner"]

print(X.shape, y.shape)
# Out:
# (4566, 38) (4566,)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
non_numeric = [i for i in X.columns if X[i].dtypes == 'object']
label_encoder.fit(y)
encoded_y = label_encoder.transform(y).reshape(-1, 1)

for i in X[non_numeric]:
    X[i] = label_encoder.fit_transform(X[i].astype(str))
# Out:
# C:\Users\nickm\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, encoded_y, random_state=1)

X_train.head()
# Out:
#             B_ev  R_odds        R_ev  B_odds  B_kd_bout  \
# 2453  190.000000    -230   43.478261     190   0.000000
# 7      43.478261     175  175.000000    -230   0.213203
# 2156   80.000000     105  105.000000    -125   0.000000
# 2107  200.000000    -240   41.666667     200   0.000000
# 403   150.000000    -160   62.500000     150   0.000000
#
#       R_tot_str_landed_bout  R_sig_str_pct_bout  B_tot_str_landed_bout  \
# 2453              59.000000            0.420000              33.000000
# 7                 56.486291            0.456082              50.838384
# 2156             138.000000            0.720000               8.000000
# 2107               4.000000            0.500000               1.000000
# 403               55.000000            0.430000              68.000000
#
#       B_pass_bout  B_sig_str_landed_bout  ...  avg_td_dif  location  B_age  \
# 2453     0.000000              27.000000  ...    0.000000        81     29
# 7        0.920274              34.871212  ...    1.560000        66     24
# 2156     1.000000               4.000000  ...   -1.600000       129     27
# 2107     0.000000               1.000000  ...    0.441176        66     36
# 403      0.000000              67.000000  ...   -1.080000        23     34
#
#       B_td_landed_bout  R_age  reach_dif  total_round_dif  B_avg_TD_landed  \
# 2453           1.00000     30       2.54                0         1.228164
# 7              0.97619     28      -5.08                3         2.250000
# 2156           0.00000     24      -7.62              -12         0.000000
# 2107           0.00000     32      -5.08               -8         1.500000
# 403            0.00000     41      -5.08              -11         0.000000
#
#       B_sig_str_attempted_bout  R_sig_str_attempted_bout
# 2453                 94.000000                116.000000
# 7                    83.124459                 86.623737
# 2156                  8.000000                113.000000
# 2107                  3.000000                  8.000000
# 403                 123.000000                126.000000
#
# [5 rows x 38 columns]

# %%
# Create a StandardScater model
from sklearn.preprocessing import StandardScaler

#Fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# Transform the training and testing data using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# One-hot encoding
from tensorflow.keras.utils import to_categorical

y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

deep_model = Sequential()
deep_model.add(Dense(units=6, activation='relu', input_dim=38))
deep_model.add(Dense(units=6, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

deep_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 234
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 290
# Trainable params: 290
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_cat,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 107/107 - 1s - loss: 0.7411 - accuracy: 0.5380
# Epoch 2/100
# 107/107 - 0s - loss: 0.6023 - accuracy: 0.6741
# Epoch 3/100
# 107/107 - 0s - loss: 0.5332 - accuracy: 0.7188
# Epoch 4/100
# 107/107 - 0s - loss: 0.4956 - accuracy: 0.7485
# Epoch 5/100
# 107/107 - 0s - loss: 0.4759 - accuracy: 0.7576
# Epoch 6/100
# 107/107 - 0s - loss: 0.4624 - accuracy: 0.7684
# Epoch 7/100
# 107/107 - 0s - loss: 0.4544 - accuracy: 0.7739
# Epoch 8/100
# 107/107 - 0s - loss: 0.4481 - accuracy: 0.7772
# Epoch 9/100
# 107/107 - 0s - loss: 0.4440 - accuracy: 0.7777
# Epoch 10/100
# 107/107 - 0s - loss: 0.4395 - accuracy: 0.7801
# Epoch 11/100
# 107/107 - 0s - loss: 0.4370 - accuracy: 0.7824
# Epoch 12/100
# 107/107 - 0s - loss: 0.4339 - accuracy: 0.7818
# Epoch 13/100
# 107/107 - 0s - loss: 0.4316 - accuracy: 0.7821
# Epoch 14/100
# 107/107 - 0s - loss: 0.4304 - accuracy: 0.7842
# Epoch 15/100
# 107/107 - 0s - loss: 0.4282 - accuracy: 0.7856
# Epoch 16/100
# 107/107 - 0s - loss: 0.4266 - accuracy: 0.7894
# Epoch 17/100
# 107/107 - 0s - loss: 0.4253 - accuracy: 0.7921
# Epoch 18/100
# 107/107 - 0s - loss: 0.4240 - accuracy: 0.7909
# Epoch 19/100
# 107/107 - 0s - loss: 0.4229 - accuracy: 0.7953
# Epoch 20/100
# 107/107 - 0s - loss: 0.4215 - accuracy: 0.7947
# Epoch 21/100
# 107/107 - 0s - loss: 0.4200 - accuracy: 0.7938
# Epoch 22/100
# 107/107 - 0s - loss: 0.4191 - accuracy: 0.7932
# Epoch 63/100
# 107/107 - 0s - loss: 0.3977 - accuracy: 0.8125
# Epoch 64/100
# 107/107 - 0s - loss: 0.3977 - accuracy: 0.8140
# Epoch 65/100
# 107/107 - 0s - loss: 0.3972 - accuracy: 0.8160
# Epoch 66/100
# 107/107 - 0s - loss: 0.3970 - accuracy: 0.8090
# Epoch 67/100
# 107/107 - 0s - loss: 0.3969 - accuracy: 0.8116
# Epoch 68/100
# 107/107 - 0s - loss: 0.3963 - accuracy: 0.8131
# Epoch 69/100
# 107/107 - 0s - loss: 0.3955 - accuracy: 0.8154
# Epoch 70/100
# 107/107 - 0s - loss: 0.3953 - accuracy: 0.8143
# Epoch 71/100
# 107/107 - 0s - loss: 0.3952 - accuracy: 0.8137
# Epoch 72/100
# 107/107 - 0s - loss: 0.3950 - accuracy: 0.8145
# Epoch 73/100
# 107/107 - 0s - loss: 0.3942 - accuracy: 0.8151
# Epoch 74/100
# 107/107 - 0s - loss: 0.3938 - accuracy: 0.8145
# Epoch 75/100
# 107/107 - 0s - loss: 0.3940 - accuracy: 0.8160
# Epoch 76/100
# 107/107 - 0s - loss: 0.3941 - accuracy: 0.8183
# Epoch 77/100
# 107/107 - 0s - loss: 0.3935 - accuracy: 0.8145
# Epoch 78/100
# 107/107 - 0s - loss: 0.3931 - accuracy: 0.8180
# Epoch 79/100
# 107/107 - 0s - loss: 0.3932 - accuracy: 0.8163
# Epoch 80/100
# 107/107 - 0s - loss: 0.3928 - accuracy: 0.8163
# Epoch 81/100
# 107/107 - 0s - loss: 0.3923 - accuracy: 0.8166
# Epoch 82/100
# 107/107 - 0s - loss: 0.3919 - accuracy: 0.8134
# Epoch 83/100
# 107/107 - 0s - loss: 0.3917 - accuracy: 0.8154
# Epoch 84/100
# 107/107 - 0s - loss: 0.3917 - accuracy: 0.8157
# Epoch 85/100
# 107/107 - 0s - loss: 0.3909 - accuracy: 0.8183
# Epoch 86/100
# 107/107 - 0s - loss: 0.3911 - accuracy: 0.8166
# Epoch 87/100
# 107/107 - 0s - loss: 0.3902 - accuracy: 0.8160
# Epoch 88/100
# 107/107 - 0s - loss: 0.3900 - accuracy: 0.8175
# Epoch 89/100
# 107/107 - 0s - loss: 0.3901 - accuracy: 0.8175
# Epoch 90/100
# 107/107 - 0s - loss: 0.3896 - accuracy: 0.8172
# Epoch 91/100
# 107/107 - 0s - loss: 0.3892 - accuracy: 0.8218
# Epoch 92/100
# 107/107 - 0s - loss: 0.3895 - accuracy: 0.8169
# Epoch 93/100
# 107/107 - 0s - loss: 0.3895 - accuracy: 0.8183
# Epoch 94/100
# 107/107 - 0s - loss: 0.3883 - accuracy: 0.8186
# Epoch 95/100
# 107/107 - 0s - loss: 0.3887 - accuracy: 0.8169
# Epoch 96/100
# 107/107 - 0s - loss: 0.3880 - accuracy: 0.8163
# Epoch 97/100
# 107/107 - 0s - loss: 0.3880 - accuracy: 0.8178
# Epoch 98/100
# 107/107 - 0s - loss: 0.3876 - accuracy: 0.8198
# Epoch 99/100
# 107/107 - 0s - loss: 0.3874 - accuracy: 0.8172
# Epoch 100/100
# 107/107 - 0s - loss: 0.3877 - accuracy: 0.8186

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_cat, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 36/36 - 0s - loss: 0.4685 - accuracy: 0.7557
# Loss: 0.4684704840183258, Accuracy: 0.7556917667388916
